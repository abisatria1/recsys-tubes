# %%
#import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Microsoft\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('Goodreadss Books.csv')
df.head()
# Out:
#    Unnamed: 0  bookId                                      title  \
# 0           0       1     Harry Potter and the Half-Blood Prince
# 1           1       2  Harry Potter and the Order of the Phoenix
# 2           2       3      Harry Potter and the Sorcerer's Stone
# 3           3       4    Harry Potter and the Chamber of Secrets
# 4           4       5   Harry Potter and the Prisoner of Azkaban
#
#                        author           series  \
# 0                J.K. Rowling  Harry Potter #6
# 1  J.K. Rowling,Mary GrandPré  Harry Potter #5
# 2  J.K. Rowling,Mary GrandPré  Harry Potter #1
# 3                J.K. Rowling  Harry Potter #2
# 4  J.K. Rowling,Mary GrandPré  Harry Potter #3
#
#                                          description  \
# 0  The war against Voldemort is not going well; e...
# 1  There is a door at the end of a silent corrido...
# 2  Harry Potter's life is miserable. His parents ...
# 3  The Dursleys were so mean and hideous that sum...
# 4  For twelve long years, the dread fortress of A...
#
#                                               genres  \
# 0  Art,Biography,Business,Children's,Christian,Cl...
# 1  Art,Biography,Business,Children's,Christian,Cl...
# 2  Art,Biography,Business,Children's,Christian,Cl...
# 3  Art,Biography,Business,Children's,Christian,Cl...
# 4  Art,Biography,Business,Children's,Christian,Cl...
#
#                                               awards  \
# 0  Locus Award Nominee for Best Young Adult Novel...
# 1  Bram Stoker Award for Works for Young Readers ...
# 2  Mythopoeic Fantasy Award for Children's Litera...
# 3  Mythopoeic Fantasy Award for Children's Litera...
# 4  Bram Stoker Award for Best Work for Young Read...
#
#                                           characters  \
# 0  Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 1  Sirius Black,Draco Malfoy,Ron Weasley,Petunia ...
# 2  Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 3  Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 4  Sirius Black,Draco Malfoy,Ron Weasley,Petunia ...
#
#                                               places  ...  \
# 0  Hogwarts School of Witchcraft and Wizardry,Eng...  ...
# 1  Hogwarts School of Witchcraft and Wizardry,Lon...  ...
# 2  London, England,Hogwarts School of Witchcraft ...  ...
# 3  Hogwarts School of Witchcraft and Wizardry,Hog...  ...
# 4  Hogwarts School of Witchcraft and Wizardry,Lon...  ...
#
#           publish_date num_pages num_ratings num_reviews avg_rating   rated_1  \
# 0  September 16th 2006     652.0   2553909.0     41470.0       4.57   13147.0
# 1       September 2004     870.0   2631427.0     44793.0       4.50   16236.0
# 2    November 1st 2003     309.0   7434783.0    117823.0       4.48  126344.0
# 3    November 1st 2003     352.0   2878196.0     55839.0       4.43   15623.0
# 4         May 1st 2004     435.0   2972519.0     58483.0       4.57   14124.0
#
#     rated_2   rated_3    rated_4    rated_5
# 0   29020.0  174312.0   608825.0  1728605.0
# 1   41738.0  231438.0   665628.0  1676387.0
# 2  147184.0  627803.0  1694206.0  4839246.0
# 3   55060.0  315917.0   787181.0  1704415.0
# 4   29105.0  214151.0   701765.0  2013374.0
#
# [5 rows x 24 columns]

# %% [markdown]
# Data Preprocessing

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'bookId', 'title', 'author', 'series', 'description',
#        'genres', 'awards', 'characters', 'places', 'isbn', 'isbn13',
#        'language', 'first_publish_date', 'publish_date', 'num_pages',
#        'num_ratings', 'num_reviews', 'avg_rating', 'rated_1', 'rated_2',
#        'rated_3', 'rated_4', 'rated_5'],
#       dtype='object')

# %%
df = df.drop(columns=['Unnamed: 0','series','awards','isbn','isbn13','first_publish_date','num_pages','rated_1','rated_2','rated_3',
                     'rated_4','rated_5','num_ratings','num_reviews'])
df.head()
# Out:
#    bookId                                      title  \
# 0       1     Harry Potter and the Half-Blood Prince
# 1       2  Harry Potter and the Order of the Phoenix
# 2       3      Harry Potter and the Sorcerer's Stone
# 3       4    Harry Potter and the Chamber of Secrets
# 4       5   Harry Potter and the Prisoner of Azkaban
#
#                        author  \
# 0                J.K. Rowling
# 1  J.K. Rowling,Mary GrandPré
# 2  J.K. Rowling,Mary GrandPré
# 3                J.K. Rowling
# 4  J.K. Rowling,Mary GrandPré
#
#                                          description  \
# 0  The war against Voldemort is not going well; e...
# 1  There is a door at the end of a silent corrido...
# 2  Harry Potter's life is miserable. His parents ...
# 3  The Dursleys were so mean and hideous that sum...
# 4  For twelve long years, the dread fortress of A...
#
#                                               genres  \
# 0  Art,Biography,Business,Children's,Christian,Cl...
# 1  Art,Biography,Business,Children's,Christian,Cl...
# 2  Art,Biography,Business,Children's,Christian,Cl...
# 3  Art,Biography,Business,Children's,Christian,Cl...
# 4  Art,Biography,Business,Children's,Christian,Cl...
#
#                                           characters  \
# 0  Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 1  Sirius Black,Draco Malfoy,Ron Weasley,Petunia ...
# 2  Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 3  Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 4  Sirius Black,Draco Malfoy,Ron Weasley,Petunia ...
#
#                                               places language  \
# 0  Hogwarts School of Witchcraft and Wizardry,Eng...  English
# 1  Hogwarts School of Witchcraft and Wizardry,Lon...  English
# 2  London, England,Hogwarts School of Witchcraft ...  English
# 3  Hogwarts School of Witchcraft and Wizardry,Hog...  English
# 4  Hogwarts School of Witchcraft and Wizardry,Lon...  English
#
#           publish_date  avg_rating
# 0  September 16th 2006        4.57
# 1       September 2004        4.50
# 2    November 1st 2003        4.48
# 3    November 1st 2003        4.43
# 4         May 1st 2004        4.57

# %%
df['title'].unique()
# Out:
# array(['Harry Potter and the Half-Blood Prince',
#        'Harry Potter and the Order of the Phoenix',
#        "Harry Potter and the Sorcerer's Stone", ..., 'The Porcelain Dove',
#        'The Fall Of The Kings', 'Die Blume der Diener'], dtype=object)

# %%
df['author'].unique()
# Out:
# array(['J.K. Rowling', 'J.K. Rowling,Mary GrandPré',
#        'W. Frederick Zimmerman', ...,
#        'Delia Sherman,Cortney Skinner,Ellen Kushner',
#        'Ellen Kushner,Delia Sherman', 'Delia Sherman,Michael Siefener'],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# bookId              0
# title             559
# author            561
# description      2687
# genres            256
# characters      15289
# places          16028
# language         2779
# publish_date     1046
# avg_rating        559
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.drop_duplicates(subset=['title'])

# %%
df = df.reset_index(drop=True)
df['bookId'] = df.index
df
# Out:
#       bookId                                      title  \
# 0          0     Harry Potter and the Half-Blood Prince
# 1          1  Harry Potter and the Order of the Phoenix
# 2          2      Harry Potter and the Sorcerer's Stone
# 3          3    Harry Potter and the Chamber of Secrets
# 4          4   Harry Potter and the Prisoner of Azkaban
# ...      ...                                        ...
# 1790    1790                        Master of the Night
# 1791    1791                             Jane's Warlord
# 1792    1792                   Blame it on the Blackout
# 1793    1793                             Walker's Widow
# 1794    1794                           Mr. and Mistress
#
#                           author  \
# 0                   J.K. Rowling
# 1     J.K. Rowling,Mary GrandPré
# 2     J.K. Rowling,Mary GrandPré
# 3                   J.K. Rowling
# 4     J.K. Rowling,Mary GrandPré
# ...                          ...
# 1790               Angela Knight
# 1791               Angela Knight
# 1792                 Heidi Betts
# 1793                 Heidi Betts
# 1794                 Heidi Betts
#
#                                             description  \
# 0     The war against Voldemort is not going well; e...
# 1     There is a door at the end of a silent corrido...
# 2     Harry Potter's life is miserable. His parents ...
# 3     The Dursleys were so mean and hideous that sum...
# 4     For twelve long years, the dread fortress of A...
# ...                                                 ...
# 1790  American agent Erin Grayson is assigned to sed...
# 1791  The next target of a time traveling killer, cr...
# 1792  Blame It on the Blackout by Heidi Betts releas...
# 1793  Clayton Walker is assigned to solve a string o...
# 1794  HIS PREGNANT MISTRESS,,She was his kept woman....
#
#                                                  genres  \
# 0     Art,Biography,Business,Children's,Christian,Cl...
# 1     Art,Biography,Business,Children's,Christian,Cl...
# 2     Art,Biography,Business,Children's,Christian,Cl...
# 3     Art,Biography,Business,Children's,Christian,Cl...
# 4     Art,Biography,Business,Children's,Christian,Cl...
# ...                                                 ...
# 1790  Art,Biography,Business,Children's,Christian,Cl...
# 1791  Art,Biography,Business,Children's,Christian,Cl...
# 1792  Art,Biography,Business,Children's,Christian,Cl...
# 1793  Art,Biography,Business,Children's,Christian,Cl...
# 1794  Art,Biography,Business,Children's,Christian,Cl...
#
#                                              characters  \
# 0     Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 1     Sirius Black,Draco Malfoy,Ron Weasley,Petunia ...
# 2     Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 3     Draco Malfoy,Ron Weasley,Petunia Dursley,Verno...
# 4     Sirius Black,Draco Malfoy,Ron Weasley,Petunia ...
# ...                                                 ...
# 1790                        Erin Grayson,Reece Champion
# 1791                             Jane Colby,Baran Arvid
# 1792                       Lucy Grainger,Peter Reynolds
# 1793                         Regan Doyle,Clayton Walker
# 1794                          Misty Vale,Cullen Elliott
#
#                                                  places language  \
# 0     Hogwarts School of Witchcraft and Wizardry,Eng...  English
# 1     Hogwarts School of Witchcraft and Wizardry,Lon...  English
# 2     London, England,Hogwarts School of Witchcraft ...  English
# 3     Hogwarts School of Witchcraft and Wizardry,Hog...  English
# 4     Hogwarts School of Witchcraft and Wizardry,Lon...  English
# ...                                                 ...      ...
# 1790                                   Atlanta, Georgia  English
# 1791                                     South Carolina  English
# 1792                           United States of America  English
# 1793                           United States of America  English
# 1794                           United States of America  English
#
#              publish_date  avg_rating
# 0     September 16th 2006        4.57
# 1          September 2004        4.50
# 2       November 1st 2003        4.48
# 3       November 1st 2003        4.43
# 4            May 1st 2004        4.57
# ...                   ...         ...
# 1790     October 5th 2004        3.88
# 1791        June 1st 2004        3.97
# 1792            June 2005        3.54
# 1793     January 8th 2002        4.10
# 1794         May 9th 2006        3.38
#
# [1795 rows x 10 columns]

# %%
df = df.drop(columns=['characters','places','publish_date','avg_rating'])

# %%
df.head()
# Out:
#    bookId                                      title  \
# 0       0     Harry Potter and the Half-Blood Prince
# 1       1  Harry Potter and the Order of the Phoenix
# 2       2      Harry Potter and the Sorcerer's Stone
# 3       3    Harry Potter and the Chamber of Secrets
# 4       4   Harry Potter and the Prisoner of Azkaban
#
#                        author  \
# 0                J.K. Rowling
# 1  J.K. Rowling,Mary GrandPré
# 2  J.K. Rowling,Mary GrandPré
# 3                J.K. Rowling
# 4  J.K. Rowling,Mary GrandPré
#
#                                          description  \
# 0  The war against Voldemort is not going well; e...
# 1  There is a door at the end of a silent corrido...
# 2  Harry Potter's life is miserable. His parents ...
# 3  The Dursleys were so mean and hideous that sum...
# 4  For twelve long years, the dread fortress of A...
#
#                                               genres language
# 0  Art,Biography,Business,Children's,Christian,Cl...  English
# 1  Art,Biography,Business,Children's,Christian,Cl...  English
# 2  Art,Biography,Business,Children's,Christian,Cl...  English
# 3  Art,Biography,Business,Children's,Christian,Cl...  English
# 4  Art,Biography,Business,Children's,Christian,Cl...  English

# %%
df['metadata_soup'] = df['title'] + ' ' + df['author'] + ' ' + df['description'] + ' ' + df['genres'] + ' ' + df['language']

# %%
df.head()
# Out:
#    bookId                                      title  \
# 0       0     Harry Potter and the Half-Blood Prince
# 1       1  Harry Potter and the Order of the Phoenix
# 2       2      Harry Potter and the Sorcerer's Stone
# 3       3    Harry Potter and the Chamber of Secrets
# 4       4   Harry Potter and the Prisoner of Azkaban
#
#                        author  \
# 0                J.K. Rowling
# 1  J.K. Rowling,Mary GrandPré
# 2  J.K. Rowling,Mary GrandPré
# 3                J.K. Rowling
# 4  J.K. Rowling,Mary GrandPré
#
#                                          description  \
# 0  The war against Voldemort is not going well; e...
# 1  There is a door at the end of a silent corrido...
# 2  Harry Potter's life is miserable. His parents ...
# 3  The Dursleys were so mean and hideous that sum...
# 4  For twelve long years, the dread fortress of A...
#
#                                               genres language  \
# 0  Art,Biography,Business,Children's,Christian,Cl...  English
# 1  Art,Biography,Business,Children's,Christian,Cl...  English
# 2  Art,Biography,Business,Children's,Christian,Cl...  English
# 3  Art,Biography,Business,Children's,Christian,Cl...  English
# 4  Art,Biography,Business,Children's,Christian,Cl...  English
#
#                                        metadata_soup
# 0  Harry Potter and the Half-Blood Prince J.K. Ro...
# 1  Harry Potter and the Order of the Phoenix J.K....
# 2  Harry Potter and the Sorcerer's Stone J.K. Row...
# 3  Harry Potter and the Chamber of Secrets J.K. R...
# 4  Harry Potter and the Prisoner of Azkaban J.K. ...

# %%
df['metadata_soup'] = df['metadata_soup'].apply(lambda x: x.lower())
df.head()
# Out:
#    bookId                                      title  \
# 0       0     Harry Potter and the Half-Blood Prince
# 1       1  Harry Potter and the Order of the Phoenix
# 2       2      Harry Potter and the Sorcerer's Stone
# 3       3    Harry Potter and the Chamber of Secrets
# 4       4   Harry Potter and the Prisoner of Azkaban
#
#                        author  \
# 0                J.K. Rowling
# 1  J.K. Rowling,Mary GrandPré
# 2  J.K. Rowling,Mary GrandPré
# 3                J.K. Rowling
# 4  J.K. Rowling,Mary GrandPré
#
#                                          description  \
# 0  The war against Voldemort is not going well; e...
# 1  There is a door at the end of a silent corrido...
# 2  Harry Potter's life is miserable. His parents ...
# 3  The Dursleys were so mean and hideous that sum...
# 4  For twelve long years, the dread fortress of A...
#
#                                               genres language  \
# 0  Art,Biography,Business,Children's,Christian,Cl...  English
# 1  Art,Biography,Business,Children's,Christian,Cl...  English
# 2  Art,Biography,Business,Children's,Christian,Cl...  English
# 3  Art,Biography,Business,Children's,Christian,Cl...  English
# 4  Art,Biography,Business,Children's,Christian,Cl...  English
#
#                                        metadata_soup
# 0  harry potter and the half-blood prince j.k. ro...
# 1  harry potter and the order of the phoenix j.k....
# 2  harry potter and the sorcerer's stone j.k. row...
# 3  harry potter and the chamber of secrets j.k. r...
# 4  harry potter and the prisoner of azkaban j.k. ...

# %%
import string
import re
#tokenizing
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

#melakukan remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

#nltk word tokenize
def word_tokenize_wrapper(text):
    return nltk.tokenize.word_tokenize(text)

def remove_number(text):
    return re.sub(r"\d+", "", text)

# %%
from nltk.corpus import stopwords

def filtering_stopword(text):
    # get Indonesian stopword 
    list_stopwords = set(stopwords.words('english'))
    #remove stopword pada list token
    tokens_without_stopword = [word for word in text if not word in list_stopwords]
    return tokens_without_stopword

def join_text(text):
    text = ' '.join(text)
    return text

# %%
df['metadata_soup'] = df['metadata_soup'].apply(remove_number)
df['metadata_soup'] = df['metadata_soup'].apply(remove_punctuation)
df['metadata_soup'] = df['metadata_soup'].apply(remove_single_char)
df['metadata_soup'] = df['metadata_soup'].apply(word_tokenize_wrapper)

# %%
df.head()
# Out:
#    bookId                                      title  \
# 0       0     Harry Potter and the Half-Blood Prince
# 1       1  Harry Potter and the Order of the Phoenix
# 2       2      Harry Potter and the Sorcerer's Stone
# 3       3    Harry Potter and the Chamber of Secrets
# 4       4   Harry Potter and the Prisoner of Azkaban
#
#                        author  \
# 0                J.K. Rowling
# 1  J.K. Rowling,Mary GrandPré
# 2  J.K. Rowling,Mary GrandPré
# 3                J.K. Rowling
# 4  J.K. Rowling,Mary GrandPré
#
#                                          description  \
# 0  The war against Voldemort is not going well; e...
# 1  There is a door at the end of a silent corrido...
# 2  Harry Potter's life is miserable. His parents ...
# 3  The Dursleys were so mean and hideous that sum...
# 4  For twelve long years, the dread fortress of A...
#
#                                               genres language  \
# 0  Art,Biography,Business,Children's,Christian,Cl...  English
# 1  Art,Biography,Business,Children's,Christian,Cl...  English
# 2  Art,Biography,Business,Children's,Christian,Cl...  English
# 3  Art,Biography,Business,Children's,Christian,Cl...  English
# 4  Art,Biography,Business,Children's,Christian,Cl...  English
#
#                                        metadata_soup
# 0  [harry, potter, and, the, halfblood, prince, j...
# 1  [harry, potter, and, the, order, of, the, phoe...
# 2  [harry, potter, and, the, sorcerers, stone, jk...
# 3  [harry, potter, and, the, chamber, of, secrets...
# 4  [harry, potter, and, the, prisoner, of, azkaba...

# %%
df['metadata_soup'] = df['metadata_soup'].apply(filtering_stopword)
df['metadata_soup'] = df['metadata_soup'].apply(join_text)

# %%
df.head()
# Out:
#    bookId                                      title  \
# 0       0     Harry Potter and the Half-Blood Prince
# 1       1  Harry Potter and the Order of the Phoenix
# 2       2      Harry Potter and the Sorcerer's Stone
# 3       3    Harry Potter and the Chamber of Secrets
# 4       4   Harry Potter and the Prisoner of Azkaban
#
#                        author  \
# 0                J.K. Rowling
# 1  J.K. Rowling,Mary GrandPré
# 2  J.K. Rowling,Mary GrandPré
# 3                J.K. Rowling
# 4  J.K. Rowling,Mary GrandPré
#
#                                          description  \
# 0  The war against Voldemort is not going well; e...
# 1  There is a door at the end of a silent corrido...
# 2  Harry Potter's life is miserable. His parents ...
# 3  The Dursleys were so mean and hideous that sum...
# 4  For twelve long years, the dread fortress of A...
#
#                                               genres language  \
# 0  Art,Biography,Business,Children's,Christian,Cl...  English
# 1  Art,Biography,Business,Children's,Christian,Cl...  English
# 2  Art,Biography,Business,Children's,Christian,Cl...  English
# 3  Art,Biography,Business,Children's,Christian,Cl...  English
# 4  Art,Biography,Business,Children's,Christian,Cl...  English
#
#                                        metadata_soup
# 0  harry potter halfblood prince jk rowling war v...
# 1  harry potter order phoenix jk rowlingmary gran...
# 2  harry potter sorcerers stone jk rowlingmary gr...
# 3  harry potter chamber secrets jk rowling dursle...
# 4  harry potter prisoner azkaban jk rowlingmary g...

# %%
# Saving indexes in a series
indices = pd.Series(df.index,index=df['title'])

# Creating tf-idf matrix
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['metadata_soup'])

# Calculating cosine similarities
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

count = CountVectorizer(stop_words = 'english')
count_matrix = count.fit_transform(df['metadata_soup'])

# %%
tfidf_matrix
# Out:
# <1795x159129 sparse matrix of type '<class 'numpy.float64'>'
# 	with 291737 stored elements in Compressed Sparse Row format>

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
df.description
# Out:
# 0       The war against Voldemort is not going well; e...
# 1       There is a door at the end of a silent corrido...
# 2       Harry Potter's life is miserable. His parents ...
# 3       The Dursleys were so mean and hideous that sum...
# 4       For twelve long years, the dread fortress of A...
#                               ...
# 1790    American agent Erin Grayson is assigned to sed...
# 1791    The next target of a time traveling killer, cr...
# 1792    Blame It on the Blackout by Heidi Betts releas...
# 1793    Clayton Walker is assigned to solve a string o...
# 1794    HIS PREGNANT MISTRESS,,She was his kept woman....
# Name: description, Length: 1795, dtype: object

# %%
cosine_sim_cv = cosine_similarity(count_matrix,count_matrix)

# %%
indices['Harry Potter and the Half-Blood Prince']
# Out:
# 0

# %%
cosine_sim_cv[3]
# Out:
# array([0.35447021, 0.32854834, 0.35303378, ..., 0.15743934, 0.14434509,
#        0.08651577])

# %%
def content_based_recommender(title,cosine_sim_cv=cosine_sim_cv,df=df,indices=indices):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim_cv[idx]))
    sim_scores = sorted(sim_scores, key = lambda x: x[1],reverse=True)
    sim_scores = sim_scores[1:11]
    book_indices = [i[0] for i in sim_scores]
    print(sim_scores)
    return df[['title','genres','author']].iloc[book_indices]

# %%
content_based_recommender("Harry Potter and the Half-Blood Prince")
# Out:
# [(3, 0.35447020912561766), (388, 0.3025455128834854), (1437, 0.29057765105126837), (288, 0.2821902486010633), (2, 0.280008960430103), (207, 0.2743516305843672), (1, 0.26422444074696677), (974, 0.2565790028953927), (5, 0.25308796943892536), (1486, 0.25295138405250944)]
#                                           title  \
# 3       Harry Potter and the Chamber of Secrets
# 388    Harry Potter and the Philosopher's Stone
# 1437        Harrius Potter et Camera Secretorum
# 288          Harry Potter Y La Piedra Filosofal
# 2         Harry Potter and the Sorcerer's Stone
# 207                                   Moby-Dick
# 1     Harry Potter and the Order of the Phoenix
# 974                             P.S. I Love You
# 5           Harry Potter and the Goblet of Fire
# 1486                     Michael Tolliver Lives
#
#                                                  genres  \
# 3     Art,Biography,Business,Children's,Christian,Cl...
# 388   Art,Biography,Business,Children's,Christian,Cl...
# 1437  Art,Biography,Business,Children's,Christian,Cl...
# 288   Art,Biography,Business,Children's,Christian,Cl...
# 2     Art,Biography,Business,Children's,Christian,Cl...
# 207   Art,Biography,Business,Children's,Christian,Cl...
# 1     Art,Biography,Business,Children's,Christian,Cl...
# 974   Art,Biography,Business,Children's,Christian,Cl...
# 5     Art,Biography,Business,Children's,Christian,Cl...
# 1486  Art,Biography,Business,Children's,Christian,Cl...
#
#                           author
# 3                   J.K. Rowling
# 388                 J.K. Rowling
# 1437  J.K. Rowling,Peter Needham
# 288                 J.K. Rowling
# 2     J.K. Rowling,Mary GrandPré
# 207              Herman Melville
# 1     J.K. Rowling,Mary GrandPré
# 974                Cecelia Ahern
# 5     J.K. Rowling,Mary GrandPré
# 1486            Armistead Maupin
